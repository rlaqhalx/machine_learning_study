# %% [markdown]
# <a href="https://colab.research.google.com/github/rlaqhalx/machine_learning_study/blob/main/Binary_logistic_regression_for_diabetes_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !kaggle datasets download -d kandij/diabetes-dataset
# !unzip diabetes-dataset.zip
# Out:
# Downloading diabetes-dataset.zip to /content
#   0% 0.00/8.92k [00:00<?, ?B/s]
# 100% 8.92k/8.92k [00:00<00:00, 19.9MB/s]
# Archive:  diabetes-dataset.zip
#   inflating: diabetes2.csv

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam, SGD
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('diabetes2.csv')
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print(df.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# Split X & Y

# %%
x_data = df.drop(columns=['Outcome'], axis=1)
x_data = x_data.astype(np.float32)

x_data.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.599998
# 1          1.0     85.0           66.0           29.0      0.0  26.600000
# 2          8.0    183.0           64.0            0.0      0.0  23.299999
# 3          1.0     89.0           66.0           23.0     94.0  28.100000
# 4          0.0    137.0           40.0           35.0    168.0  43.099998
#
#    DiabetesPedigreeFunction   Age
# 0                     0.627  50.0
# 1                     0.351  31.0
# 2                     0.672  32.0
# 3                     0.167  21.0
# 4                     2.288  33.0

# %%
y_data = df[['Outcome']]
y_data = y_data.astype(np.float32)

y_data.head(5)
# Out:
#    Outcome
# 0      1.0
# 1      0.0
# 2      1.0
# 3      0.0
# 4      1.0

# %% [markdown]
# Standarization

# %%
scaler = StandardScaler()
x_data_scaled = scaler.fit_transform(x_data)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_data_scaled, y_data, test_size=0.2, random_state=2021)

# check the shape for each dataset
print(x_train.shape, x_val.shape)
print(y_train.shape, y_val.shape)
# Out:
# (614, 8) (154, 8)
# (614, 1) (154, 1)

# %%
model = Sequential([
    Dense(1, activation = 'sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.01), metrics=['acc'])

model.fit(
    x_train,
    y_train,
    validation_data=(x_val, y_val),
    epochs=50
)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# 20/20 [==============================] - 0s 8ms/step - loss: 1.0644 - acc: 0.4853 - val_loss: 1.0508 - val_acc: 0.4481
# Epoch 2/50
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0419 - acc: 0.4967 - val_loss: 1.0274 - val_acc: 0.4675
# Epoch 3/50
# 20/20 [==============================] - 0s 3ms/step - loss: 1.0206 - acc: 0.5016 - val_loss: 1.0049 - val_acc: 0.4740
# Epoch 4/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9990 - acc: 0.5098 - val_loss: 0.9842 - val_acc: 0.4740
# Epoch 5/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9793 - acc: 0.5147 - val_loss: 0.9627 - val_acc: 0.4935
# Epoch 6/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.9590 - acc: 0.5212 - val_loss: 0.9427 - val_acc: 0.5000
# Epoch 7/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.9399 - acc: 0.5244 - val_loss: 0.9226 - val_acc: 0.5000
# Epoch 8/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9209 - acc: 0.5261 - val_loss: 0.9036 - val_acc: 0.5260
# Epoch 9/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9017 - acc: 0.5391 - val_loss: 0.8845 - val_acc: 0.5584
# Epoch 10/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8837 - acc: 0.5570 - val_loss: 0.8656 - val_acc: 0.5649
# Epoch 11/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8660 - acc: 0.5603 - val_loss: 0.8479 - val_acc: 0.5714
# Epoch 12/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.8489 - acc: 0.5619 - val_loss: 0.8320 - val_acc: 0.5714
# Epoch 13/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8332 - acc: 0.5700 - val_loss: 0.8155 - val_acc: 0.5779
# Epoch 14/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8174 - acc: 0.5782 - val_loss: 0.7999 - val_acc: 0.5909
# Epoch 15/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8018 - acc: 0.5831 - val_loss: 0.7841 - val_acc: 0.6039
# Epoch 16/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7866 - acc: 0.5945 - val_loss: 0.7697 - val_acc: 0.6104
# Epoch 17/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7726 - acc: 0.5993 - val_loss: 0.7553 - val_acc: 0.6039
# Epoch 18/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7585 - acc: 0.6091 - val_loss: 0.7417 - val_acc: 0.6104
# Epoch 19/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7452 - acc: 0.6173 - val_loss: 0.7291 - val_acc: 0.6104
# Epoch 20/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7327 - acc: 0.6205 - val_loss: 0.7169 - val_acc: 0.6169
# Epoch 21/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7211 - acc: 0.6319 - val_loss: 0.7048 - val_acc: 0.6364
# Epoch 22/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7089 - acc: 0.6384 - val_loss: 0.6938 - val_acc: 0.6299
# Epoch 23/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6975 - acc: 0.6401 - val_loss: 0.6828 - val_acc: 0.6299
# Epoch 24/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6866 - acc: 0.6482 - val_loss: 0.6726 - val_acc: 0.6364
# Epoch 25/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6764 - acc: 0.6498 - val_loss: 0.6623 - val_acc: 0.6364
# Epoch 26/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6667 - acc: 0.6564 - val_loss: 0.6534 - val_acc: 0.6364
# Epoch 27/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6573 - acc: 0.6547 - val_loss: 0.6445 - val_acc: 0.6169
# Epoch 28/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6483 - acc: 0.6580 - val_loss: 0.6361 - val_acc: 0.6299
# Epoch 29/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6399 - acc: 0.6629 - val_loss: 0.6281 - val_acc: 0.6494
# Epoch 30/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6316 - acc: 0.6726 - val_loss: 0.6205 - val_acc: 0.6494
# Epoch 31/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6240 - acc: 0.6840 - val_loss: 0.6135 - val_acc: 0.6494
# Epoch 32/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6166 - acc: 0.6857 - val_loss: 0.6068 - val_acc: 0.6494
# Epoch 33/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6095 - acc: 0.6873 - val_loss: 0.6004 - val_acc: 0.6494
# Epoch 34/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6026 - acc: 0.6889 - val_loss: 0.5943 - val_acc: 0.6558
# Epoch 35/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5965 - acc: 0.6889 - val_loss: 0.5881 - val_acc: 0.6753
# Epoch 36/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5902 - acc: 0.6840 - val_loss: 0.5824 - val_acc: 0.6948
# Epoch 37/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5847 - acc: 0.6922 - val_loss: 0.5773 - val_acc: 0.7078
# Epoch 38/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5792 - acc: 0.6987 - val_loss: 0.5723 - val_acc: 0.7143
# Epoch 39/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5739 - acc: 0.7068 - val_loss: 0.5675 - val_acc: 0.7143
# Epoch 40/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5692 - acc: 0.7068 - val_loss: 0.5630 - val_acc: 0.7013
# Epoch 41/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5647 - acc: 0.7085 - val_loss: 0.5590 - val_acc: 0.7013
# Epoch 42/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5603 - acc: 0.7052 - val_loss: 0.5552 - val_acc: 0.7013
# Epoch 43/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5563 - acc: 0.7134 - val_loss: 0.5511 - val_acc: 0.7208
# Epoch 44/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5523 - acc: 0.7117 - val_loss: 0.5477 - val_acc: 0.7208
# Epoch 45/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5488 - acc: 0.7117 - val_loss: 0.5444 - val_acc: 0.7273
# Epoch 46/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5453 - acc: 0.7134 - val_loss: 0.5413 - val_acc: 0.7338
# Epoch 47/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5421 - acc: 0.7150 - val_loss: 0.5382 - val_acc: 0.7468
# Epoch 48/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5389 - acc: 0.7134 - val_loss: 0.5353 - val_acc: 0.7532
# Epoch 49/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5359 - acc: 0.7199 - val_loss: 0.5328 - val_acc: 0.7532
# Epoch 50/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5333 - acc: 0.7231 - val_loss: 0.5302 - val_acc: 0.7532
